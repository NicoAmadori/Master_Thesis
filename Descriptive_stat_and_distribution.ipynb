# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAmadori/Master_Thesis/blob/main/Descriptive_stat_and_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yahooFinance
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm
import statsmodels.api as sm
from scipy import stats
from scipy.stats import moment
# %matplotlib inline

# %%
start = "2016-01-01"
end = '2023-12-31'

# %%
XLC = yahooFinance.download('XLC', start=start, end=end)['Adj Close']
XLY = yahooFinance.download('XLY', start=start, end=end)['Adj Close']
XLV = yahooFinance.download('XLV', start=start, end=end)['Adj Close']
XTN = yahooFinance.download('XTN', start=start, end=end)['Adj Close']
XLE = yahooFinance.download('XLE', start=start, end=end)['Adj Close']
XLF = yahooFinance.download('XLF', start=start, end=end)['Adj Close']
FINX = yahooFinance.download('FINX', start=start, end=end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
XLC_returns = XLC.pct_change().dropna()
XLY_returns = XLY.pct_change().dropna()
XLV_returns = XLV.pct_change().dropna()
XTN_returns = XTN.pct_change().dropna()
XLE_returns = XLE.pct_change().dropna()
XLF_returns = XLF.pct_change().dropna()
FINX_returns = FINX.pct_change().dropna()

# %%
def calculate_statistics(data):
    mean = np.mean(data)
    sd = np.std(data)
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data)
    data_max = np.max(data)
    data_min = np.min(data)
    ACF = cf_returns = sm.tsa.acf(data, nlags=5)
    ACF_abs = acf_abs_returns = sm.tsa.acf(np.abs(data), nlags=5)
    JB = stats.jarque_bera(data)
    LB_Q = sm.stats.acorr_ljungbox(data,lags=20)
    LB_Q_squared = sm.stats.acorr_ljungbox(np.square(data),lags=20)

    return mean, sd, skewness, kurtosis, data_max, data_min, ACF,ACF_abs, JB, LB_Q, LB_Q_squared

# %%
XLC_stats = calculate_statistics(XLC_returns)
XLY_stats = calculate_statistics(XLY_returns)
XLV_stats = calculate_statistics(XLV_returns)
XTN_stats = calculate_statistics(XTN_returns)
XLE_stats = calculate_statistics(XLE_returns)
XLF_stats = calculate_statistics(XLF_returns)
FINX_stats = calculate_statistics(FINX_returns)

# %%
print("XLC Set Statistics:")
print("Mean:", XLC_stats[0])
print("Standard Deviation:", XLC_stats[1])
print("Skewness:", XLC_stats[2])
print("Excess Kurtosis:", XLC_stats[3])
print("Max:", XLC_stats[4])
print("Min:", XLC_stats[5])
print("ACF:", XLC_stats[6])
print("ACF Abs:", XLC_stats[7])
print("JB test:", XLC_stats[8])
print("LB-Q(20):", XLC_stats[9])
print("LB-Q(20) Squared:", XLC_stats[10])
# Out:
# XLC Set Statistics:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eadadcfb784a> in <cell line: 2>()
#       1 print("XLC Set Statistics:")
# ----> 2 print("Mean:", XLC_stats[0])
#       3 print("Standard Deviation:", XLC_stats[1])
#       4 print("Skewness:", XLC_stats[2])
#       5 print("Excess Kurtosis:", XLC_stats[3])
#
# NameError: name 'XLC_stats' is not defined

# %%
print("XLY Set Statistics:")
print("Mean:", XLY_stats[0])
print("Standard Deviation:", XLY_stats[1])
print("Skewness:", XLY_stats[2])
print("Excess Kurtosis:", XLY_stats[3])
print("Max:", XLY_stats[4])
print("Min:", XLY_stats[5])
print("ACF:", XLY_stats[6])
print("ACF Abs:", XLY_stats[7])
print("JB test:", XLY_stats[8])
print("LB-Q(20):", XLY_stats[9])
print("LB-Q(20) Squared:", XLY_stats[10])
# Out:
# XLY Set Statistics:
# Mean: 0.0005623328778973883
# Standard Deviation: 0.013885327451379369
# Skewness: -0.5994398199823168
# Excess Kurtosis: 8.455120445906907
# Max: 0.09379647754275466
# Min: -0.12668624692995567
# ACF: [ 1.         -0.06542968  0.07487216 -0.02168172 -0.01100298  0.01816911]
# ACF Abs: [1.         0.30462359 0.38155795 0.32797062 0.31843882 0.32158042]
# JB test: SignificanceResult(statistic=6110.622433643107, pvalue=0.0)
# LB-Q(20):        lb_stat     lb_pvalue
# 1     8.622027  3.321221e-03
# 2    19.917818  4.730432e-05
# 3    20.865537  1.122666e-04
# 4    21.109728  3.011935e-04
# 5    21.775909  5.775219e-04
# 6    38.312966  9.756909e-07
# 7    56.576581  7.255532e-10
# 8    79.890384  5.143634e-14
# 9   107.981300  3.785862e-19
# 10  112.846555  1.421120e-19
# 11  115.109837  1.739484e-19
# 12  115.260517  5.422891e-19
# 13  115.486264  1.563652e-18
# 14  117.817202  1.681972e-18
# 15  129.913361  2.210997e-20
# 16  131.606662  3.128097e-20
# ...

# %%
print("XLV Set Statistics:")
print("Mean:", XLV_stats[0])
print("Standard Deviation:", XLV_stats[1])
print("Skewness:", XLV_stats[2])
print("Excess Kurtosis:", XLV_stats[3])
print("Max:", XLV_stats[4])
print("Min:", XLV_stats[5])
print("ACF:", XLV_stats[6])
print("ACF Abs:", XLV_stats[7])
print("JB test:", XLV_stats[8])
print("LB-Q(20):", XLV_stats[9])
print("LB-Q(20) Squared:", XLV_stats[10])
# Out:
# XLV Set Statistics:
# Mean: 0.0004512387340487667
# Standard Deviation: 0.010796120206113173
# Skewness: -0.22122427009855594
# Excess Kurtosis: 9.986109153869545
# Max: 0.07705705693235854
# Min: -0.09861027925373156
# ACF: [ 1.         -0.11644679  0.09524845 -0.02729597 -0.06408675  0.04995726]
# ACF Abs: [1.         0.33901098 0.38148135 0.33821986 0.31853285 0.33410767]
# JB test: SignificanceResult(statistic=8372.307207984179, pvalue=0.0)
# LB-Q(20):        lb_stat     lb_pvalue
# 1    27.309569  1.733514e-07
# 2    45.590222  1.259532e-10
# 3    47.092288  3.321998e-10
# 4    55.376381  2.709410e-11
# 5    60.412804  9.986679e-12
# 6    90.161275  2.805042e-17
# 7   127.339193  2.259516e-24
# 8   166.749102  6.188142e-32
# 9   204.433450  3.894946e-39
# 10  219.132173  1.623848e-41
# 11  219.191515  7.610574e-41
# 12  219.193179  3.488950e-40
# 13  236.489494  4.060138e-43
# 14  246.693559  1.387010e-44
# 15  258.431302  2.269876e-46
# 16  269.047847  6.297851e-48
# ...

# %%
print("XTN Set Statistics:")
print("Mean:", XTN_stats[0])
print("Standard Deviation:", XTN_stats[1])
print("Skewness:", XTN_stats[2])
print("Excess Kurtosis:", XTN_stats[3])
print("Max:", XTN_stats[4])
print("Min:", XTN_stats[5])
print("ACF:", XTN_stats[6])
print("ACF Abs:", XTN_stats[7])
print("JB test:", XTN_stats[8])
print("LB-Q(20):", XTN_stats[9])
print("LB-Q(20) Squared:", XTN_stats[10])
# Out:
# XTN Set Statistics:
# Mean: 0.0005104670170514349
# Standard Deviation: 0.016166616126429417
# Skewness: -0.2642329875113605
# Excess Kurtosis: 5.471897572596763
# Max: 0.12043792564431421
# Min: -0.10891300388674463
# ACF: [ 1.         -0.00822233  0.05150156 -0.02971997 -0.03987112  0.02497942]
# ACF Abs: [1.         0.25075235 0.26716636 0.22908543 0.21982884 0.1984878 ]
# JB test: SignificanceResult(statistic=2532.2628748393063, pvalue=0.0)
# LB-Q(20):       lb_stat     lb_pvalue
# 1    0.136160  7.121288e-01
# 2    5.480778  6.454522e-02
# 3    7.261471  6.401467e-02
# 4   10.467927  3.324167e-02
# 5   11.727112  3.872447e-02
# 6   19.850677  2.944038e-03
# 7   46.377300  7.381732e-08
# 8   54.874728  4.669461e-09
# 9   69.124154  2.260653e-11
# 10  69.261742  6.154955e-11
# 11  69.722363  1.379479e-10
# 12  70.109605  3.055278e-10
# 13  72.383659  2.913794e-10
# 14  73.870091  3.811293e-10
# 15  80.044317  6.855536e-11
# 16  80.168474  1.551625e-10
# ...

# %%
print("XLE Set Statistics:")
print("Mean:", XLE_stats[0])
print("Standard Deviation:", XLE_stats[1])
print("Skewness:", XLE_stats[2])
print("Excess Kurtosis:", XLE_stats[3])
print("Max:", XLE_stats[4])
print("Min:", XLE_stats[5])
print("ACF:", XLE_stats[6])
print("ACF Abs:", XLE_stats[7])
print("JB test:", XLE_stats[8])
print("LB-Q(20):", XLE_stats[9])
print("LB-Q(20) Squared:", XLE_stats[10])
# Out:
# XLE Set Statistics:
# Mean: 0.0005319486134574995
# Standard Deviation: 0.019849752447845967
# Skewness: -0.4057926330989645
# Excess Kurtosis: 13.070916033228283
# Max: 0.1603736910954745
# Min: -0.2014120335896774
# ACF: [ 1.         -0.05275342  0.0492137  -0.00872956  0.00355042  0.04491627]
# ACF Abs: [1.         0.27424112 0.28444707 0.33438074 0.32092965 0.30224059]
# JB test: SignificanceResult(statistic=14370.900661105818, pvalue=0.0)
# LB-Q(20):       lb_stat     lb_pvalue
# 1    5.604811  1.791122e-02
# 2   10.485128  5.286685e-03
# 3   10.638758  1.384857e-02
# 4   10.664183  3.060900e-02
# 5   14.735476  1.155448e-02
# 6   22.289799  1.072813e-03
# 7   57.021801  5.918307e-10
# 8   60.405334  3.880939e-10
# 9   62.670410  4.086807e-10
# 10  63.357747  8.345123e-10
# 11  63.812746  1.800759e-09
# 12  64.406847  3.508625e-09
# 13  71.721581  3.863207e-10
# 14  74.384405  3.068512e-10
# 15  75.828247  4.010500e-10
# 16  76.222603  7.918484e-10
# 17  80.071161  3.725183e-10
# ...

# %%
print("XLF Set Statistics:")
print("Mean:", XLF_stats[0])
print("Standard Deviation:", XLF_stats[1])
print("Skewness:", XLF_stats[2])
print("Excess Kurtosis:", XLF_stats[3])
print("Max:", XLF_stats[4])
print("Min:", XLF_stats[5])
print("ACF:", XLF_stats[6])
print("ACF Abs:", XLF_stats[7])
print("JB test:", XLF_stats[8])
print("LB-Q(20):", XLF_stats[9])
print("LB-Q(20) Squared:", XLF_stats[10])
# Out:
# XLF Set Statistics:
# Mean: 0.0005276654226773152
# Standard Deviation: 0.014790749115398787
# Skewness: -0.2292961470276008
# Excess Kurtosis: 14.162771362846431
# Max: 0.13156624658718097
# Min: -0.13709319650564056
# ACF: [ 1.         -0.12281243  0.10866616 -0.01605518 -0.0712998   0.0457638 ]
# ACF Abs: [1.         0.42339492 0.42238321 0.37755487 0.37658858 0.33992147]
# JB test: SignificanceResult(statistic=16824.897397171346, pvalue=0.0)
# LB-Q(20):        lb_stat     lb_pvalue
# 1    30.376971  3.557263e-08
# 2    54.170813  1.725669e-12
# 3    54.690477  7.993622e-12
# 4    64.944281  2.643699e-13
# 5    69.170666  1.524680e-13
# 6    92.852491  7.736390e-18
# 7   154.034690  5.765383e-30
# 8   173.004746  3.023962e-33
# 9   194.059755  5.817947e-37
# 10  195.456864  1.428598e-36
# 11  195.465495  6.483097e-36
# 12  195.604694  2.630809e-35
# 13  209.896842  1.261158e-37
# 14  215.272120  4.105161e-38
# 15  229.081131  2.465486e-40
# 16  231.698041  2.877675e-40
# ...

# %%
print("FINX Set Statistics:")
print("Mean:", FINX_stats[0])
print("Standard Deviation:", FINX_stats[1])
print("Skewness:", FINX_stats[2])
print("Excess Kurtosis:", FINX_stats[3])
print("Max:", FINX_stats[4])
print("Min:", FINX_stats[5])
print("ACF:", FINX_stats[6])
print("ACF Abs:", FINX_stats[7])
print("JB test:", FINX_stats[8])
print("LB-Q(20):", FINX_stats[9])
print("LB-Q(20) Squared:", FINX_stats[10])
# Out:
# FINX Set Statistics:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f733b4e4e54b> in <cell line: 2>()
#       1 print("FINX Set Statistics:")
# ----> 2 print("Mean:", FINX_stats[0])
#       3 print("Standard Deviation:", FINX_stats[1])
#       4 print("Skewness:", FINX_stats[2])
#       5 print("Excess Kurtosis:", FINX_stats[3])
#
# NameError: name 'FINX_stats' is not defined

# %%
import seaborn as sns
from scipy.stats import norm, t, gennorm
import statsmodels.api as sm

# %%
start = "2016-01-01"
end = '2023-12-31'

# %%
XLV = yahooFinance.download('XLV', start=start, end=end)['Adj Close']
XLY = yahooFinance.download('XLY', start=start, end=end)['Adj Close']
XLE = yahooFinance.download('XLE', start=start, end=end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
XLV_returns = XLV.pct_change().dropna()
XLY_returns = XLY.pct_change().dropna()
XLE_returns = XLE.pct_change().dropna()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))


plt.hist(XLV_returns, bins=500, density=True, alpha=0.6, color='blue', label='Empirical Distribution')

# norm
mu, std = norm.fit(XLV_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')

#  t
params_t = t.fit(XLV_returns)
p_t = t.pdf(x, *params_t)
plt.plot(x, p_t, 'r', linewidth=2, label='Student\'s t Distribution')

# skewt
params_skewt = sm.OLS(XLV_returns, sm.add_constant(np.arange(len(XLV_returns)))).fit().params
p_skewt = t.pdf(x, *params_t)
plt.plot(x, p_skewt, 'g', linewidth=2, label='Skewed t Distribution')

# ged
params_ged = gennorm.fit(XLV_returns)
p_ged = gennorm.pdf(x, *params_ged)
plt.plot(x, p_ged, 'purple', linewidth=2, label='Generalized Error Distribution')

plt.title('Histogram of XLV Returns and Model Comparisons')
plt.xlim(-0.2,0.2)
plt.xlabel('Returns')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))


plt.hist(XLY_returns, bins=500, density=True, alpha=0.6, color='orange', label='Empirical Distribution')

# norm
mu, std = norm.fit(XLY_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')

#  t
params_t = t.fit(XLY_returns)
p_t = t.pdf(x, *params_t)
plt.plot(x, p_t, 'r', linewidth=2, label='Student\'s t Distribution')

# skewt
params_skewt = sm.OLS(XLY_returns, sm.add_constant(np.arange(len(XLY_returns)))).fit().params
p_skewt = t.pdf(x, *params_t)
plt.plot(x, p_skewt, 'g', linewidth=2, label='Skewed t Distribution')

# ged
params_ged = gennorm.fit(XLY_returns)
p_ged = gennorm.pdf(x, *params_ged)
plt.plot(x, p_ged, 'purple', linewidth=2, label='Generalized Error Distribution')

plt.title('Histogram of XLY Returns and Model Comparisons')
plt.xlim(-0.2,0.2)
plt.xlabel('Returns')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))


plt.hist(XLE_returns, bins=500, density=True, alpha=0.6, color='purple', label='Empirical Distribution')

# norm
mu, std = norm.fit(XLE_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')

#  t
params_t = t.fit(XLE_returns)
p_t = t.pdf(x, *params_t)
plt.plot(x, p_t, 'r', linewidth=2, label='Student\'s t Distribution')

# skewt
params_skewt = sm.OLS(XLE_returns, sm.add_constant(np.arange(len(XLE_returns)))).fit().params
p_skewt = t.pdf(x, *params_t)
plt.plot(x, p_skewt, 'g', linewidth=2, label='Skewed t Distribution')

# ged
params_ged = gennorm.fit(XLE_returns)
p_ged = gennorm.pdf(x, *params_ged)
plt.plot(x, p_ged, 'purple', linewidth=2, label='Generalized Error Distribution')

plt.title('Histogram of XLE Returns and Model Comparisons')
plt.xlim(-0.2,0.2)
plt.xlabel('Returns')
plt.ylabel('Density')
plt.legend()
plt.show()
